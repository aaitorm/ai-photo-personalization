# %%
import pathlib

NBS_DIR = pathlib.Path().resolve()
REPO_DIR = NBS_DIR.parent
DATA_DIR = REPO_DIR / "data"
GENERATED_DIR = DATA_DIR / "generated"
GENERATED_DIR.mkdir(exist_ok=True, parents=True)
REFERENCES_DIR = DATA_DIR / "references"
REFERENCES_DIR.mkdir(exist_ok=True, parents=True)

# %%
from decouple import config

REPLICATE_API_TOKEN = config("REPLICATE_API_TOKEN")
REPLICATE_MODEL= config("REPLICATE_MODEL", default="aaitorm/superme-aitor-v1")
REPLICATE_MODEL_VERSION= config("REPLICATE_MODEL_VERSION", default="76fd9d004a50354c0d509dda96b7945139f83c9bcd86dc011010ffc11c3d0ea7")

# %%
from replicate.client import Client

replicate_client = Client(api_token=REPLICATE_API_TOKEN)

# %%
reference_image_path = REFERENCES_DIR / "spider-man.webp"
image = open(reference_image_path, 'rb')

# %%
model = f"{REPLICATE_MODEL}:{REPLICATE_MODEL_VERSION}"
prompt = "a photo of TOK adult man dressed up as spider-man"

responses = replicate_client.run(
    model,
    input={
        "image": image,
        "model": "dev",
        "prompt": prompt,
        "num_outputs": 4,
        "output_format": "jpg",
    }
)
image.close()
# Out:
# ---------------------------------------------------------------------------
# ModelError                                Traceback (most recent call last)
# Cell In[9], line 4
#       1 model = f"{REPLICATE_MODEL}:{REPLICATE_MODEL_VERSION}"
#       2 prompt = "a photo of TOK adult man dressed up as spider-man"
# ----> 4 responses = replicate_client.run(
#       5     model,
#       6     input={
#       7         "image": image,
#       8         "model": "dev",
#       9         "prompt": prompt,
#      10         "num_outputs": 4,
#      11         "output_format": "jpg",
#      12     }
#      13 )
#      14 image.close()
#
# File c:\AITORMILICUA\super-me-photo-ai-api\venv\Lib\site-packages\replicate\client.py:175, in Client.run(self, ref, input, use_file_output, **params)
#     163 def run(
#     164     self,
#     165     ref: str,
#    (...)    169     **params: Unpack["Predictions.CreatePredictionParams"],
#     170 ) -> Union[Any, Iterator[Any]]:  # noqa: ANN401
#     171     """
#     172     Run a model and wait for its output.
#     173     """
# --> 175     return run(self, ref, input, use_file_output=use_file_output, **params)
#
# File c:\AITORMILICUA\super-me-photo-ai-api\venv\Lib\site-packages\replicate\run.py:81, in run(client, ref, input, use_file_output, **params)
#      78     prediction.wait()
#      80 if prediction.status == "failed":
# ---> 81     raise ModelError(prediction)
#      83 # Return an iterator for the completed prediction when needed.
#      84 if (
#      85     version
#      86     and _has_output_iterator_array_type(version)
#      87     and prediction.output is not None
#      88 ):
#
# ModelError: cannot identify image file '/tmp/tmpcb5zyoabdownload'

# %%
import random
session_id = random.randint(1_000, 40_000)
for i, output in enumerate(responses):
    fname = f"{i}-{session_id}.jpg"
    outpath = GENERATED_DIR / fname
    with open(outpath, 'wb') as f:
        f.write(output.read())
